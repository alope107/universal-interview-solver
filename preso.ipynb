# %% [markdown]
# <div class="rise-lg">
#
# # Beating Almost Every Interview Question With One Line of Python
#
# ## Auberon López (they/them)
# ## September 2026
# </div>

# %% [markdown]
# <div class="rise-xl">
#
# ```python
# type('',(),{'__eq__':id})
# ```
#
# </div>

# %%
def reverse_string(s):
    return s[::1]

assert reverse_string("hello") == "olleh"
assert reverse_string("Sweden") == "nedewS"
assert reverse_string("") == ""
print("All tests passed!")
